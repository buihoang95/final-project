# %% [markdown]
# # Sentiment Analysis - Chotot user feedback classification

# %% [markdown]
# "**Chotot Nha** is using [Surveygizmo](https://www.surveygizmo.com/), an online survey platform, to get **user feedback** about Chotot Nha.
# As a business analysis, we need to analyze the **user's feedback**, which feedback is **negative**, **positive** or neutral. Moreover, Nhà BA wants to know more about **bad feedbacks**, which kind of problem which related to this feedback such as **ad-quality**, **payment method**, **premium features**,... In order to help chotot Nha BA identify the kind of feedback, especially bad ones, we might add an AI-brain to help them classify user feedback, then BA can categorize, analyze feedback easily as their kind"

# %% [markdown]
# ## Sample Data

# %%
import pandas as pd
import numpy as np
import re
data = pd.read_csv("data.csv")

data.head(100)
# Out:
#                                                  data       label
# 0                                     Cam on cho tốt.    positive
# 1                                                 Tốt    positive
# 2      Tin dag chua dc tot lam.. Len hay mat tim k dc     overall
# 3   Điều chỉnh hay quy định lại giá bán là ...  ad_quality
# 4                                                 Tốt    positive
# 5                                                  Ok    positive
# 6   Hiện chưa có vấn đề gì! Vì cũng thỉnh thoảng m...     neutral
# 7                                             Rất tốt    positive
# 8       Sửa nội dung đã đăng : không cho sửa danh mục   ad_review
# 9                                     Cho tot qua tot    positive
# 10                                                 Ko    positive
# 11        Co 1 so Thong tin bds dang khg dung su that  ad_quality
# 12                   Muc đăng tin dê dang hơn .cam ơn   ad_review
# 13  đa số hình ảnh không đúng như thực tế, nên khắ...  ad_quality
# 14                                                Tốt    positive
# 15  Tìm kiếm sản phẩm cho kết quả rất ít, ...       ui_ux
# 16  Loại bỏ các tin đăng đã quá lâu , lọc ca...  ad_quality
# 17  Co nhiu tin dang tap nhap de nghi tin xoa bo v...  ad_quality
# 18                                           Hài lòng    positive
# 19                                                Tốt    positive
# 20                                              Không     neutral
# 21                                             Cảm ơn    positive
# 22  Phải xác định dc nguồn gốc của người đăng, chứ...  ad_quality
# 23  Tin bán nhà, bán đất được đăng lẫn lộn trong m...  ad_quality
# 24  Trang đăng hay hạn chế số lượng tin đăng yêu t...       ui_ux
# 25                  Chuc cho tốt ngay cang phát trien    positive
# 26  Nen gt nhung du an moi phat trien gia thap de ...       ui_ux
# 27                         Cần duyệt bài chặt chẽ hơn   ad_review
# 28  Tin nhiều nhưng kém chất lượng. Nên phân chia ...  ad_quality
# 29  Mọi thứ đều tốt. Mong xuất hiện dc nhà phù hợp...    positive
# ..                                                ...         ...
# 70                                         Ok rất tốt    positive
# 71                                                 Ko     neutral
# 72       Thông tin rât tôt , chi tiêt , dể tìm kiếm .       ui_ux
# 73  Nên lọc bài để dễ tìm hơn, nhiều bài đăng khu ...       ui_ux
# 74  Nâng cao tính xác thực và hạn chế những tin đă...  ad_quality
# 75                                                  o     neutral
# 76           nên cho đăng thêm clip/ video sẽ tốt hơn       ui_ux
# 77                                 Mong dc sự giúp đỡ      others
# 78                             Nên kiểm tra thông tin  ad_quality
# 79  Phải phân biệt rõ giưa môi giới và cá nhân. Ph...  ad_quality
# 80                           Hạn chế hiện tin mô giới  ad_quality
# 81  thông tin nhà đất cần được xác thưc, thêm chi ...       ui_ux
# 82                 Chứng minh nhân dân người đănv tin  ad_quality
# 83          Đănh bán hoặc mua phải đúng nhay giờ       ui_ux
# 84                                     vậy là tốt rồi    positive
# 85                             đăng ngày mới cập nhật       ui_ux
# 86  Trang đã làm tốt. Nếu dc thì kiểm duyệt nội du...    positive
# 87                                              Không     neutral
# 88                                      Good. I like.    positive
# 89                  Can duyet thong tin kh chat luong   ad_review
# 90  Mong rằng thông tin đươc duyệt trên Chợ Tốt nh...  ad_quality
# 91                                                tốt    positive
# 92                  Giup moi nguoi tim duoc nha vua y    positive
# 93                             Can mua xa kia k200 cu      others
# 94                                              Không     neutral
# 95                                                Tot    positive
# 96                                                Tot    positive
# 97                      Cho đầy đủ địa chỉ cụ thể hơn       ui_ux
# 98                                   Dang vhi tiet ro       ui_ux
# 99                                       Cò vạc nhiều  ad_quality
#
# [100 rows x 2 columns]

# %%
data["label"].unique()
# Out:
# array(['positive', 'overall', 'ad_quality', 'neutral', 'ad_review',
#        'ui_ux', 'others', 'payment_method', 'premium_features'],
#       dtype=object)

# %%
groupby = data.groupby(["label"])
groupby.describe()
# Out:
#                   data         \
#                  count unique
# label
# ad_quality         460    339
# ad_review          527    417
# neutral            193     65
# others              43     29
# overall             37     25
# payment_method     142    120
# positive           758    457
# premium_features   285    252
# ui_ux              397    283
#
#
#                                                                 top freq
# label
# ad_quality                                           bỏ bớt tin rác    3
# ad_review                                       duyệt tin nhanh hơn    8
# neutral                                                       không   82
# others                                           Mong dc sự giúp đỡ    2
# overall           đừng bán thông tin cá nhân người đăng tin cho ...    2
# payment_method              đồng tốt nên mở nạp bằng cạt điện thoại    2
# positive                                                        tốt   99
# premium_features                 quảng cáo đến người dùng nhiều hơn    2
# ui_ux                                        đăng ngày mới cập nhật    4

# %%
sampleData = data["data"].sample(20).values
sampleData
# Out:
# array(['chợ_tốt rất tốt rồi',
#        'nên để lại tính năng chat giữa ng mua và bán',
#        'tôi muốn chợ_tốt duyệt tin nhanh hơn',
#        'rất tốt duyệt tin mau lẹ cảm on các thành viên ban quãn trị chợ_tốt',
#        'để tiện hơn trong việc đưa tin bạn nên để 1 email cho 2 sdt sử dụng',
#        'không', 'phần nạp tiền cần đơn giản dễ hiểu dễ nạp hơn',
#        'bây giờ có nhiều người đăng tin lừa đảo quá treo đầu dê bán thịt chó đăng bán nhà thạnh lộc kêu dẫn đi xem hẹn gặp cổng mêtro lê văn khương khi ra thì toàn nhân viên tư vấn dự án long an hoặc khi hen địa điểm ra tới nơi thì gọi không nghe máy',
#        'những người cần việc làm thực sự thì hãy đăng tin gọi tuyển toàn từ chối bận',
#        'khó đăng tin trên chợ_tốt quá Đầu tư tin đăng nhưng ko được duyệt',
#        'Việc thanh toán qua thẻ nội địa vẫn gặp khó trong việc thực hiện',
#        'Có chính sách ái ngộ cho người bán.để người bán tích cực đăng hơn',
#        'tốt', 'Hỗ trợ duyệt tin nhanh', 'tốt', 'tệ phức tạp khó khăn',
#        'cần hướng dẫn cách nạp tiền để đăng tin',
#        'phí đăng tin cao quá nên lấy chi phí từ nhà mạng miễn phí tin đăng hoặc tính phí thấp cho ng dùng',
#        'duyệt tin lâu và quá khó', 'Không'], dtype=object)

# %% [markdown]
# **It can be seen that user feedback have some particular features:**
# * Contain both sign and no sign (chợ tốt and cho tot)
# * Imbalance dataset
# * We must tokenize chợ tốt to chợ_tốt because "tốt" is the confused keyword
# * Number is redundant features

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# #### Convert to lowercase

# %%
def convertToLower(s):
    return s.lower()

sampleData = list(map(convertToLower, sampleData))
sampleData
# Out:
# ['chợ_tốt rất tốt rồi',
#  'nên để lại tính năng chat giữa ng mua và bán',
#  'tôi muốn chợ_tốt duyệt tin nhanh hơn',
#  'rất tốt duyệt tin mau lẹ cảm on các thành viên ban quãn trị chợ_tốt',
#  'để tiện hơn trong việc đưa tin bạn nên để 1 email cho 2 sdt sử dụng',
#  'không',
#  'phần nạp tiền cần đơn giản dễ hiểu dễ nạp hơn',
#  'bây giờ có nhiều người đăng tin lừa đảo quá treo đầu dê bán thịt chó đăng bán nhà thạnh lộc kêu dẫn đi xem hẹn gặp cổng mêtro lê văn khương khi ra thì toàn nhân viên tư vấn dự án long an hoặc khi hen địa điểm ra tới nơi thì gọi không nghe máy',
#  'những người cần việc làm thực sự thì hãy đăng tin gọi tuyển toàn từ chối bận',
#  'khó đăng tin trên chợ_tốt quá đầu tư tin đăng nhưng ko được duyệt',
#  'việc thanh toán qua thẻ nội địa vẫn gặp khó trong việc thực hiện',
#  'có chính sách ái ngộ cho người bán.để người bán tích cực đăng hơn',
#  'tốt',
#  'hỗ trợ duyệt tin nhanh',
#  'tốt',
#  'tệ phức tạp khó khăn',
#  'cần hướng dẫn cách nạp tiền để đăng tin',
#  'phí đăng tin cao quá nên lấy chi phí từ nhà mạng miễn phí tin đăng hoặc tính phí thấp cho ng dùng',
#  'duyệt tin lâu và quá khó',
#  'không']

# %% [markdown]
# #### Remove number

# %%
def removeNumber(s):
    return re.sub(r"\d+", "", s)

sampleData = list(map(removeNumber, sampleData))
sampleData
# Out:
# ['chợ_tốt rất tốt rồi',
#  'nên để lại tính năng chat giữa ng mua và bán',
#  'tôi muốn chợ_tốt duyệt tin nhanh hơn',
#  'rất tốt duyệt tin mau lẹ cảm on các thành viên ban quãn trị chợ_tốt',
#  'để tiện hơn trong việc đưa tin bạn nên để  email cho  sdt sử dụng',
#  'không',
#  'phần nạp tiền cần đơn giản dễ hiểu dễ nạp hơn',
#  'bây giờ có nhiều người đăng tin lừa đảo quá treo đầu dê bán thịt chó đăng bán nhà thạnh lộc kêu dẫn đi xem hẹn gặp cổng mêtro lê văn khương khi ra thì toàn nhân viên tư vấn dự án long an hoặc khi hen địa điểm ra tới nơi thì gọi không nghe máy',
#  'những người cần việc làm thực sự thì hãy đăng tin gọi tuyển toàn từ chối bận',
#  'khó đăng tin trên chợ_tốt quá đầu tư tin đăng nhưng ko được duyệt',
#  'việc thanh toán qua thẻ nội địa vẫn gặp khó trong việc thực hiện',
#  'có chính sách ái ngộ cho người bán.để người bán tích cực đăng hơn',
#  'tốt',
#  'hỗ trợ duyệt tin nhanh',
#  'tốt',
#  'tệ phức tạp khó khăn',
#  'cần hướng dẫn cách nạp tiền để đăng tin',
#  'phí đăng tin cao quá nên lấy chi phí từ nhà mạng miễn phí tin đăng hoặc tính phí thấp cho ng dùng',
#  'duyệt tin lâu và quá khó',
#  'không']

# %% [markdown]
# #### Remove punctuation

# %%
def removePunctuation(s):
    s = re.sub(r"[^A-Za-z0-9\u00C0-\u02B8\u037F-\u051D\u1E00-\u1F79 ]+", "", s)
    return s.strip()

sampleData = list(map(removePunctuation, sampleData))
sampleData
# Out:
# ['chợtốt rất tốt rồi',
#  'nên để lại tính năng chat giữa ng mua và bán',
#  'tôi muốn chợtốt duyệt tin nhanh hơn',
#  'rất tốt duyệt tin mau lẹ cảm on các thành viên ban quãn trị chợtốt',
#  'để tiện hơn trong việc đưa tin bạn nên để  email cho  sdt sử dụng',
#  'không',
#  'phần nạp tiền cần đơn giản dễ hiểu dễ nạp hơn',
#  'bây giờ có nhiều người đăng tin lừa đảo quá treo đầu dê bán thịt chó đăng bán nhà thạnh lộc kêu dẫn đi xem hẹn gặp cổng mêtro lê văn khương khi ra thì toàn nhân viên tư vấn dự án long an hoặc khi hen địa điểm ra tới nơi thì gọi không nghe máy',
#  'những người cần việc làm thực sự thì hãy đăng tin gọi tuyển toàn từ chối bận',
#  'khó đăng tin trên chợtốt quá đầu tư tin đăng nhưng ko được duyệt',
#  'việc thanh toán qua thẻ nội địa vẫn gặp khó trong việc thực hiện',
#  'có chính sách ái ngộ cho người bánđể người bán tích cực đăng hơn',
#  'tốt',
#  'hỗ trợ duyệt tin nhanh',
#  'tốt',
#  'tệ phức tạp khó khăn',
#  'cần hướng dẫn cách nạp tiền để đăng tin',
#  'phí đăng tin cao quá nên lấy chi phí từ nhà mạng miễn phí tin đăng hoặc tính phí thấp cho ng dùng',
#  'duyệt tin lâu và quá khó',
#  'không']

# %% [markdown]
# #### Remove stopword

# %%
f = open("stopword.txt", "r").readlines()
stopwords = [s.replace("\n", "") for s in f]
print(stopwords)

def removeStopword(s):
    res = filter(lambda x: x not in stopwords, s.split(" "))
    return " ".join(res)

sampleData = list(map(removeStopword, sampleData))
sampleData
# Out:
# ['các', 'cái', 'càng', 'chiếc', 'cho', 'chứ', 'cứ', 'của', 'cùng', 'cũng', 'đã', 'đang', 'đây', 'để', 'đều', 'điều', 'do', 'đó', 'được', 'gì', 'khi', 'không', 'là', 'lại', 'lên', 'lúc', 'mà', 'mỗi', 'này', 'nên', 'nếu', 'ngay', 'như', 'nhưng', 'những', 'nơi', 'nữa', 'qua', 'ra', 'rằng', 'rồi', 'sẽ', 'so', 'tại', 'thì', 'từ', 'và', 'vẫn', 'vậy', 'vì', 'với', 'vừa']
# ['chợtốt rất tốt',
#  'tính năng chat giữa ng mua bán',
#  'tôi muốn chợtốt duyệt tin nhanh hơn',
#  'rất tốt duyệt tin mau lẹ cảm on thành viên ban quãn trị chợtốt',
#  'tiện hơn trong việc đưa tin bạn  email  sdt sử dụng',
#  '',
#  'phần nạp tiền cần đơn giản dễ hiểu dễ nạp hơn',
#  'bây giờ có nhiều người đăng tin lừa đảo quá treo đầu dê bán thịt chó đăng bán nhà thạnh lộc kêu dẫn đi xem hẹn gặp cổng mêtro lê văn khương toàn nhân viên tư vấn dự án long an hoặc hen địa điểm tới gọi nghe máy',
#  'người cần việc làm thực sự hãy đăng tin gọi tuyển toàn chối bận',
#  'khó đăng tin trên chợtốt quá đầu tư tin đăng ko duyệt',
#  'việc thanh toán thẻ nội địa gặp khó trong việc thực hiện',
#  'có chính sách ái ngộ người bánđể người bán tích cực đăng hơn',
#  'tốt',
#  'hỗ trợ duyệt tin nhanh',
#  'tốt',
#  'tệ phức tạp khó khăn',
#  'cần hướng dẫn cách nạp tiền đăng tin',
#  'phí đăng tin cao quá lấy chi phí nhà mạng miễn phí tin đăng hoặc tính phí thấp ng dùng',
#  'duyệt tin lâu quá khó',
#  '']

# %% [markdown]
# #### Tokenization

# %%
def tokenization(s):
    s = s.replace("chợ tốt", "chợ_tốt")
    s = s.replace("cho tot", "cho_tot")
    return s
sampleData = list(map(tokenization, sampleData))
sampleData
# Out:
# ['chợtốt rất tốt',
#  'tính năng chat giữa ng mua bán',
#  'tôi muốn chợtốt duyệt tin nhanh hơn',
#  'rất tốt duyệt tin mau lẹ cảm on thành viên ban quãn trị chợtốt',
#  'tiện hơn trong việc đưa tin bạn  email  sdt sử dụng',
#  '',
#  'phần nạp tiền cần đơn giản dễ hiểu dễ nạp hơn',
#  'bây giờ có nhiều người đăng tin lừa đảo quá treo đầu dê bán thịt chó đăng bán nhà thạnh lộc kêu dẫn đi xem hẹn gặp cổng mêtro lê văn khương toàn nhân viên tư vấn dự án long an hoặc hen địa điểm tới gọi nghe máy',
#  'người cần việc làm thực sự hãy đăng tin gọi tuyển toàn chối bận',
#  'khó đăng tin trên chợtốt quá đầu tư tin đăng ko duyệt',
#  'việc thanh toán thẻ nội địa gặp khó trong việc thực hiện',
#  'có chính sách ái ngộ người bánđể người bán tích cực đăng hơn',
#  'tốt',
#  'hỗ trợ duyệt tin nhanh',
#  'tốt',
#  'tệ phức tạp khó khăn',
#  'cần hướng dẫn cách nạp tiền đăng tin',
#  'phí đăng tin cao quá lấy chi phí nhà mạng miễn phí tin đăng hoặc tính phí thấp ng dùng',
#  'duyệt tin lâu quá khó',
#  '']

# %% [markdown]
# #### Steming

# %%
def steming(s):
    return s

# %% [markdown]
# ## Append sentence without sign

# %%
import unicodedata

def removeAccent(s):
#     s = s.decode('utf-8')
    s = re.sub(u'Đ', 'D', s)
    s = re.sub(u'đ', 'd', s)
    return unicodedata.normalize('NFKD', str(s)).encode('ASCII', 'ignore').decode()

addedData = data
for index, row in data.iterrows():
    addedData.loc[index] = [removeAccent(row['data']), row["label"]]
data = data.append(added_data)
data
# Out:
#                                                    data           label
# 0                                       Cam on cho tot.        positive
# 1                                                   Tot        positive
# 2        Tin dag chua dc tot lam.. Len hay mat tim k dc         overall
# 3     Dieu chinh hay quy dinh lai gia ban la gia the...      ad_quality
# 4                                                   Tot        positive
# 5                                                    Ok        positive
# 6     Hien chua co van de gi! Vi cung thinh thoang m...         neutral
# 7                                               Rat tot        positive
# 8         Sua noi dung da dang : khong cho sua danh muc       ad_review
# 9                                       Cho tot qua tot        positive
# 10                                                   Ko        positive
# 11          Co 1 so Thong tin bds dang khg dung su that      ad_quality
# 12                     Muc dang tin de dang hon .cam on       ad_review
# 13    da so hinh anh khong dung nhu thuc te, nen kha...      ad_quality
# 14                                                  Tot        positive
# 15    Tim kiem san pham cho ket qua rat it, ko hai long           ui_ux
# 16    Loai bo cac tin dang da qua lau , loc cac tin ...      ad_quality
# 17    Co nhiu tin dang tap nhap de nghi tin xoa bo v...      ad_quality
# 18                                             Hai long        positive
# 19                                                  Tot        positive
# 20                                                Khong         neutral
# 21                                               Cam on        positive
# 22    Phai xac dinh dc nguon goc cua nguoi dang, chu...      ad_quality
# 23    Tin ban nha, ban dat duoc dang lan lon trong m...      ad_quality
# 24    Trang dang hay han che so luong tin dang yeu t...           ui_ux
# 25                    Chuc cho tot ngay cang phat trien        positive
# 26    Nen gt nhung du an moi phat trien gia thap de ...           ui_ux
# 27                           Can duyet bai chat che hon       ad_review
# 28    Tin nhieu nhung kem chat luong. Nen phan chia ...      ad_quality
# 29    Moi thu deu tot. Mong xuat hien dc nha phu hop...        positive
# ...                                                 ...             ...
# 2812                              nap tien don gian hon  payment_method
# 2813  cach thanh toan cua cho tot qua do tai khoan t...  payment_method
# 2814  khong the mua dong tot duoc nen ca nhom chung ...  payment_method
# 2815  lap the dong tot qua the dien thi nhieu nguoi ...  payment_method
# 2816          luc nay day tin bang tin nhanh khong duoc  payment_method
# 2817                          nap tien dang tin kho qua  payment_method
# 2818  cac phuong thuc thanh toan phuc tap qua cho nh...  payment_method
# 2819              cach nop tien de dang tin hoi ruom ra  payment_method
# 2820  cho tot nap tien vao the dien thoai de day tin...  payment_method
# 2821     co phuong thuc thanh toan bang card dien thoai  payment_method
# 2822  hinh thuc thanh toan nen don giang hon de tao ...  payment_method
# 2823              kho khan viec thanh toan khi dang bds  payment_method
# 2824                            kho nap tien de day bai  payment_method
# 2825                         khong biet cach thanh toan  payment_method
# 2826  khong thanh toan bang cart dt duoc la mot diem...  payment_method
# 2827  ko co tien ich day tin qua sms va quan ly tin ...  payment_method
# 2828                        ko nap dc cac mat thoi gian  payment_method
# 2829  muon thanh toan nap the cao mobifone ma khong ...  payment_method
# 2830  muon day tin nhung cach thanh toan kho qua kho...  payment_method
# 2831  nap the dong tot khong duoc va phi qua cao cho...  payment_method
# 2832                    nap tien bang momo thi ngon qua  payment_method
# 2833  nap dong tot kho khan hon luc truoc tom lai mu...  payment_method
# 2834  nen cho ban tru tien trong tai khoan nop cac n...  payment_method
# 2835   nen de nop tai khoan bang card de tien giao dich  payment_method
# 2836  tao trang chat truc tuyen cho nguoi dung de li...  payment_method
# 2837  thanh lap them nhieu diem nap tk dong tottui m...  payment_method
# 2838  thanh toan bang the card dien thoai cho thuan ...  payment_method
# 2839                      thanh toan dang tin bang dtdd  payment_method
# 2840  toi co y kien la cho_tot khong nen ap dung hin...  payment_method
# 2841  dung cai thien nhieu kho su dungdien hinh nhu ...  payment_method
#
# [5684 rows x 2 columns]

# %% [markdown]
# ## Create Model

# %%
def cleanData(s):
    s = converToLower(s)
    s = removeNumber(s)
    s = removePunctuation(s)
    s = removeStopword(s)
    s = tokenization(s)
    s = steming(s)
    return s

# %%
def tokenizer(s):
    return s.split()

# %% [markdown]
# #### train test split

# %%
labelMapping = {
    "ad_quality": 0,
    "ad_review": 1,
    "neutral": 2,
    "others": 3,
    "overall": 4,
    "payment_method": 5,
    "positive": 6,
    "premium_features": 7,
    "ui_ux": 8
}

data = data.dropna()

y = data["label"].map(labelMapping)
X = data["data"]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(stop_words=stopwords,
                        tokenizer=tokenizer,
                        preprocessor=cleanData,ngram_range=(1,2))

# A pipeline is what chains several steps together, once the initial exploration is done. 
# For example, some codes are meant to transform features — normalise numericals, or turn text into vectors, 
# or fill up missing data, they are transformers; other codes are meant to predict variables by fitting an algorithm,
# they are estimators. Pipeline chains all these together which can then be applied to training data
clf = Pipeline([('vect', tfidf),
                ('clf', LogisticRegression(random_state=0,multi_class="multinomial",solver="lbfgs"))])
clf.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('vect', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 2), norm='l2',
#         preprocessor=<function clean..., penalty='l2', random_state=0, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False))])

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Now apply those above metrics to evaluate your model
# Your code here
prediction = clf.predict(X_test)

# %%
print(classification_report(y_true=y_test, y_pred=prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       206
#            1       0.93      0.95      0.94       210
#            2       0.93      0.94      0.94        72
#            3       1.00      0.62      0.76        13
#            4       1.00      0.13      0.24        15
#            5       0.87      0.85      0.86        55
#            6       0.95      0.95      0.95       282
#            7       0.95      0.91      0.93       121
#            8       0.89      0.94      0.91       163
#
#    micro avg       0.93      0.93      0.93      1137
#    macro avg       0.94      0.81      0.83      1137
# weighted avg       0.93      0.93      0.92      1137

# %%
accuracy_score(y_test, prediction)
# Out:
# 0.9287598944591029
